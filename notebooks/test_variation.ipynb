# %%
import pandas as pd

# %%
df = pd.read_csv("../data/gold/202603/202603_gold_instituicao_label_snapshot.csv")

# %%
df['variacao_percentual'] = ((df['valor_total'] - df['preco_entrada']) / df['preco_entrada'])
